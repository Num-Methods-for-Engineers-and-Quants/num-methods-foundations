# %% [markdown]
# # ✏️ Root Finding for Engineers and Quants: Bisection vs Newton in Python
#
# > *"Sometimes, solving for 'x' means solving for flow, interest rates, or financial stability."*
#
# As part of my journey from civil engineering into quantitative finance, I’ve been revisiting classical numerical methods—this time, through the lens of real-world problems.
#
# Root-finding is one of those foundational tools that shows up **everywhere**: in pipe flow calculations, IRR estimation, and nonlinear financial modeling.
#
# ---
#
# ## 📌 Why Root Finding Matters
#
# - **In civil engineering**: Solve for unknown pressures in a network where nonlinear equations (like Darcy-Weisbach) rule the flow.
# - **In finance**: Back out internal rate of return (IRR) or implied volatility from observed prices.
# - **In machine learning**: Tune hyperparameters or solve cost functions with closed-form roots.
#
# Let’s explore **two core methods**:
# 1. **Bisection Method** – slow but guaranteed
# 2. **Newton-Raphson Method** – fast but risky
#
# ---
#
# ## 🧮 The Problem
#
# We’ll find the root of this nonlinear function:
#
# ```python
# f(x) = x³ - x - 2
# ```

# %% [markdown]
# Let's Visualize It:

# %%
# Let's Visualize it:
import numpy as np
import matplotlib.pyplot as plt

def f(x):
    return x**3 - x - 2

x = np.linspace(0, 3, 400)
y = f(x)

plt.plot(x, y)
plt.axhline(0, color='gray', linestyle='--')
plt.title("Function: f(x) = x³ - x - 2")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.grid(True)
plt.show()
